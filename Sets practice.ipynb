# %%
a={"Ironman", "Hulk", "Thor", "Antman"}
print(a)
# Out:
# {'Ironman', 'Thor', 'Antman', 'Hulk'}

# %%
for x in a:
    print(x)
# Out:
# Ironman
# Thor
# Antman
# Hulk

# %%
a.add("Spiderman")
print(a)
# Out:
# {'Ironman', 'Hulk', 'Spiderman', 'Antman', 'Thor'}

# %%
a.pop()
print(a)
# Out:
# {'Hulk', 'Spiderman', 'Antman', 'Thor'}

# %%
a.remove("Thor")
print(a)
# Out:
# {'Hulk', 'Spiderman', 'Antman'}

# %%
a.discard("Hulk")
print(a)
# Out:
# {'Spiderman', 'Antman'}

# %%
b=a.copy()
print(b)
# Out:
# {'Spiderman', 'Antman'}

# %%
a={"Ironman", "Hulk", "Thor", "Antman"}
b={"Superman", "Batman", "Flash"}
c={"Hulk", "Thor"}
print(a,b,c)
# Out:
# {'Ironman', 'Thor', 'Antman', 'Hulk'} {'Flash', 'Batman', 'Superman'} {'Thor', 'Hulk'}

# %%
print(a.isdisjoint(b))
print(a.isdisjoint(c))             #check common values
# Out:
# True
# False

# %%
print(a.issubset(b))
print(c.issubset(a))
# Out:
# False
# True

# %%
print(b.issuperset(a))
print(a.issuperset(c))
# Out:
# False
# True

# %%
a.update(b)
print(a)
# Out:
# {'Batman', 'Ironman', 'Thor', 'Hulk', 'Flash', 'Antman', 'Superman'}

# %%
a={"Ironman", "Hulk", "Thor", "Antman"}
b={"Superman", "Batman", "Flash"}
c={"Hulk", "Thor","Vision"}
a.update(c)
print(a)
# Out:
# {'Ironman', 'Vision', 'Hulk', 'Antman', 'Thor'}

# %%
print(a.clear())
print(a)
# Out:
# None
# set()

# %%
a={"Ironman", "Hulk", "Thor", "Antman"}
b={"Superman", "Batman", "Flash"}
c={"Hulk", "Thor"}

# %%
print(a.union(c))
# Out:
# {'Ironman', 'Hulk', 'Antman', 'Thor'}

# %%
print(a.difference(c))
print(a)                                         #does not change original set
# Out:
# {'Ironman', 'Antman'}
# {'Ironman', 'Thor', 'Antman', 'Hulk'}

# %%
a.difference_update(c)                     #Changes the original set
print(a)
# Out:
# {'Ironman', 'Antman'}

# %%
print(a.intersection_update(c))
print(a)
# Out:
# None
# {'Hulk', 'Thor'}

# %%
a.intersection_update(c)
print(a)
# Out:
# {'Hulk', 'Thor'}

# %%
x=a.symmetric_difference(c)
print(x)
# Out:
# {'Antman', 'Ironman'}

# %%
a.symmetric_difference_update(c)
print(a)
# Out:
# {'Ironman', 'Antman'}

# %%
#find minimum and maximum in a set
a={12,56,13,9,8,48,35,2,25}
maximum=max(a)
minimum= min(a)
print("Maximum is:", maximum)
print("Minimum is:", minimum)
# Out:
# Maximum is: 56
# Minimum is: 2

# %%
# find common elements in 3 lists using sets
a=[1,5,6,8,2]
b=[4,5,6,7]
c=[1,9,6,2,5]
print(set(a) & set(b) & set(c))
# Out:
# {5, 6}

# %%
# find difference between two sets
a=set(a)
c=set(c)

print(a.difference(c))
print(c.difference(a))
# Out:
# {8}
# {9}
